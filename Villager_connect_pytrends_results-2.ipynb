# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)

# %%
pytrend_res = pd.read_csv("final_villager_list_v2.csv")

# %%
pytrend_res
# Out:
#                                                  query      value  \
# 0                 admiral animal crossing new horizons   202400.0
# 1                                                  NaN        NaN
# 2                   animal crossing new horizons agnes   451600.0
# 3                          agnes house animal crossing   236800.0
# 4                    agnes personality animal crossing   118000.0
# 5                         animal crossing new horizons   824550.0
# 6                      al animal crossing new horizons   791450.0
# 7                           al gorilla animal crossing    86800.0
# 8                                                  NaN        NaN
# 9                   alice animal crossing new horizons   672800.0
# 10                                 alice in wonderland   567050.0
# 11                                                 NaN        NaN
# 12                 amelia animal crossing new horizons   322750.0
# ...

# %%
pytrend_res['Name'] = pytrend_res['searchitem'].str.replace(r' Animal Crossing','')

# %%
pytrend_res['Name2'] = pytrend_res['Name'].str.lower()

# %%
pytrend_res
# Out:
#                                                  query      value  \
# 0                 admiral animal crossing new horizons   202400.0
# 1                                                  NaN        NaN
# 2                   animal crossing new horizons agnes   451600.0
# 3                          agnes house animal crossing   236800.0
# 4                    agnes personality animal crossing   118000.0
# 5                         animal crossing new horizons   824550.0
# 6                      al animal crossing new horizons   791450.0
# 7                           al gorilla animal crossing    86800.0
# 8                                                  NaN        NaN
# 9                   alice animal crossing new horizons   672800.0
# 10                                 alice in wonderland   567050.0
# 11                                                 NaN        NaN
# 12                 amelia animal crossing new horizons   322750.0
# ...

# %%
villagers_acnh = pd.read_csv("villagers.csv")

# %%
villagers_acnh
# Out:
#          Name    Species  Gender Personality      Hobby Birthday  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun
# 5       Alice      Koala  Female      Normal  Education   19-Aug
# 6        Alli  Alligator  Female      Snooty    Fashion    8-Nov
# 7      Amelia      Eagle  Female      Snooty      Music   19-Nov
# 8    Anabelle   Anteater  Female       Peppy    Fashion   16-Feb
# 9     Anchovy       Bird    Male        Lazy       Play    4-Mar
# 10      Angus       Bull    Male      Cranky    Fitness   30-Apr
# 11   Anicotti      Mouse  Female       Peppy    Fashion   24-Feb
# 12      Ankha        Cat  Female      Snooty     Nature   22-Sep
# ...

# %%
pytrend_res['query'] = pytrend_res['query'].fillna('unknown')

# %%
pytrend_res['keep_value'] = pytrend_res.apply(lambda x: x['Name2'] in x['query'], axis = 1)

# %%
pytrend_res
# Out:
#                                                  query      value  \
# 0                 admiral animal crossing new horizons   202400.0
# 1                                              unknown        NaN
# 2                   animal crossing new horizons agnes   451600.0
# 3                          agnes house animal crossing   236800.0
# 4                    agnes personality animal crossing   118000.0
# 5                         animal crossing new horizons   824550.0
# 6                      al animal crossing new horizons   791450.0
# 7                           al gorilla animal crossing    86800.0
# 8                                              unknown        NaN
# 9                   alice animal crossing new horizons   672800.0
# 10                                 alice in wonderland   567050.0
# 11                                             unknown        NaN
# 12                 amelia animal crossing new horizons   322750.0
# ...

# %%
#fixing 'Ohare' name to 'O'Hare

# %%
pytrend_res['Name'] = np.where(pytrend_res['Name'] == 'OHare', "O'Hare", pytrend_res['Name'])

# %%
#need to fix June update vs June the villager

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['Name'] == 'June', False, pytrend_res['keep_value'])

# %%
#need to fix Lily the villager because all the searches done on her are actually for
#the lily of the valley flower and its different colors and not for "her" as a villager.

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['Name'] == 'Lily', False, pytrend_res['keep_value'])

# %%
#doing something similar for maple

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['query'].str.contains('maple leaf'),False,pytrend_res['keep_value'])

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['query'].str.contains('maple leaves'),False,pytrend_res['keep_value'])

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['query'].str.contains('maple diy'),False,pytrend_res['keep_value'])

# %%
#doing a similar update for peaches because 'how to get peaches' refers to the fruit
#and peachtree in the game not the villager

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['query'].str.contains('how to get peaches'),False,pytrend_res['keep_value'])

# %%
#we will have to do the same for "cherry" the searches do not refer to the villager but the 
#cherry blossoms and cherry tree and cherry salmon.

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['query'].str.contains('cherry blossom'),False,pytrend_res['keep_value'])

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['query'].str.contains('cherry tree'),False,pytrend_res['keep_value'])

# %%
pytrend_res['keep_value'] = np.where(pytrend_res['query'].str.contains('cherry salmon'),False,pytrend_res['keep_value'])

# %%
#now we can add up total value searches for each villager but first if keep value is False
#we will update the search "value" to zero

# %%
pytrend_res['value'] = np.where(pytrend_res['keep_value'] == False, 0,pytrend_res['value'])

# %%
pytrend_chk = pytrend_res[pytrend_res['keep_value']==False]

# %%
pytrend_chk
# Out:
#                                                  query  value  \
# 1                                              unknown    0.0
# 8                                              unknown    0.0
# 11                                             unknown    0.0
# 13                                             unknown    0.0
# 15                                             unknown    0.0
# 16                                             unknown    0.0
# 17                               animal crossing video    0.0
# 23                        animal crossing egyptian cat    0.0
# 26                               animal crossing lucky    0.0
# 28                                                anka    0.0
# 31                                               ankah    0.0
# 32                              zucker animal crossing    0.0
# 33                                      camel by camel    0.0
# 35                               lolly animal crossing    0.0
# ...

# %%
pytrend_final = pytrend_res[pytrend_res['keep_value']==True]

# %%
pytrend_final
# Out:
#                                                  query      value  \
# 0                 admiral animal crossing new horizons   202400.0
# 2                   animal crossing new horizons agnes   451600.0
# 3                          agnes house animal crossing   236800.0
# 4                    agnes personality animal crossing   118000.0
# 5                         animal crossing new horizons   824550.0
# 6                      al animal crossing new horizons   791450.0
# 7                           al gorilla animal crossing    86800.0
# 9                   alice animal crossing new horizons   672800.0
# 10                                 alice in wonderland   567050.0
# 12                 amelia animal crossing new horizons   322750.0
# 14                anchovy animal crossing new horizons   640700.0
# 18                         ankha animal crossing video   651750.0
# 19                                          ankha zone   458650.0
# ...

# %%
pytrend_search_count = pytrend_res.groupby(by=['Name'])[['value']].sum()

# %%
pytrend_search_count = pytrend_search_count.reset_index()

# %%
pytrend_search_count = pytrend_search_count.sort_values(by='value', ascending=False)

# %%
pytrend_search_count.shape
# Out:
# (391, 2)

# %%
pytrend_search_count
# Out:
#          Name      value
# 298   Raymond  3899300.0
# 87       Clay  3503450.0
# 12      Ankha  2800650.0
# 59    Bubbles  2314100.0
# 310       Rod  2068650.0
# 232  Merengue  1746250.0
# 3          Al  1702800.0
# 186      Judy  1569200.0
# 157     Gonzo  1478950.0
# 228   Marshal  1343250.0
# 329     Sherb  1297750.0
# 256     Olive  1253850.0
# 111     Diana  1252750.0
# 358     Teddy  1252150.0
# 92       Coco  1244350.0
# 5       Alice  1239850.0
# 155    Gloria  1210150.0
# 188    Julian  1188050.0
# 299   Reneigh  1178550.0
# 227    Marina  1130500.0
# 345  Stitches  1101250.0
# 30       Beau  1087800.0
# 41      Billy  1061750.0
# 19      Audie  1059000.0
# 254  Octavian  1011100.0
# 116       Dom   997950.0
# 129      Erik   987200.0
# 336    Sparro   956100.0
# 277    Phoebe   954050.0
# 331      Skye   943350.0
# 235      Mint   928100.0
# 223     Maple   891450.0
# 224    Marcel   874250.0
# 306     Roald   868500.0
# 136      Flip   863350.0
# 32      Bella   862200.0
# ...

# %%
#changing column name "value" to "Total_Google_Searches"

# %%
pytrend_search_count = pytrend_search_count.rename(columns={"value": "Total_Google_Searches"})

# %%
#Now we will merge this with the villagers acnh data

# %%
villagers_acnh_google = villagers_acnh.merge(pytrend_search_count, left_on="Name",
                                            right_on = "Name", how = "left")

# %%
villagers_acnh_google
# Out:
#          Name    Species  Gender Personality      Hobby Birthday  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun
# 5       Alice      Koala  Female      Normal  Education   19-Aug
# 6        Alli  Alligator  Female      Snooty    Fashion    8-Nov
# 7      Amelia      Eagle  Female      Snooty      Music   19-Nov
# 8    Anabelle   Anteater  Female       Peppy    Fashion   16-Feb
# 9     Anchovy       Bird    Male        Lazy       Play    4-Mar
# 10      Angus       Bull    Male      Cranky    Fitness   30-Apr
# 11   Anicotti      Mouse  Female       Peppy    Fashion   24-Feb
# 12      Ankha        Cat  Female      Snooty     Nature   22-Sep
# ...

# %%
#Bringing in the Poll Results which came from avid ACNH players voting on fav villagers

# %%
ACP_POLL_FIN = pd.read_csv("ACP_FinalDF.csv")

# %%
ACP_POLL_FIN = ACP_POLL_FIN.rename(columns = {'Tally':'Poll_Results',"Villagers":"Name"})

# %%
ACP_POLL_FIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    397 non-null    int64
#  1   Name          397 non-null    object
#  2   Poll_Results  397 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.4+ KB

# %%
ACP_POLL_FIN = ACP_POLL_FIN.drop("Unnamed: 0",axis=1)

# %%
ACP_POLL_FIN
# Out:
#          Name  Poll_Results
# 0     Marshal       26600.0
# 1     Raymond       24565.0
# 2       Sherb       17495.0
# 3      Zucker       15342.0
# 4        Judy       13054.0
# 5      Marina       11723.0
# 6    Stitches       10867.0
# 7       Ankha       10811.0
# 8       Audie       10551.0
# 9       Fauna       10248.0
# 10       Beau        9994.0
# 11        Dom        9864.0
# 12       Erik        9850.0
# 13   Merengue        9646.0
# 14      Merry        9622.0
# 15      Roald        9165.0
# 16        Bob        9158.0
# 17       Coco        8801.0
# 18      Lucky        8195.0
# 19      Lolly        7961.0
# 20      Molly        7866.0
# 21      Maple        7330.0
# 22      Diana        7155.0
# 23    Ketchup        6384.0
# 24     Cherry        5245.0
# 25      Poppy        5124.0
# 26     Julian        4896.0
# 27      Tangy        4883.0
# 28     Apollo        4840.0
# 29     Pietro        4789.0
# 30      Rosie        4549.0
# 31      Apple        4504.0
# ...

# %%
#merging to add on the poll results by villager name

# %%
Final_Villagers_ACNH = villagers_acnh_google.merge(ACP_POLL_FIN, left_on="Name",
                                                  right_on='Name', how="left")

# %%
#creating the total popularity villager value, may want to rate weight
#and factorize the poll results value

# %%
Final_Villagers_ACNH['Overall_Popularity'] = Final_Villagers_ACNH['Total_Google_Searches']+Final_Villagers_ACNH['Poll_Results']

# %%
Final_Villagers_ACNH
# Out:
#          Name    Species  Gender Personality      Hobby Birthday  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun
# 5       Alice      Koala  Female      Normal  Education   19-Aug
# 6        Alli  Alligator  Female      Snooty    Fashion    8-Nov
# 7      Amelia      Eagle  Female      Snooty      Music   19-Nov
# 8    Anabelle   Anteater  Female       Peppy    Fashion   16-Feb
# 9     Anchovy       Bird    Male        Lazy       Play    4-Mar
# 10      Angus       Bull    Male      Cranky    Fitness   30-Apr
# 11   Anicotti      Mouse  Female       Peppy    Fashion   24-Feb
# 12      Ankha        Cat  Female      Snooty     Nature   22-Sep
# ...

# %%
Final_Villagers_ACNH.to_csv('Final_Villagers_ACNH.csv')

# %%
Final_Villagers_ACNH
# Out:
#          Name    Species  Gender Personality      Hobby Birthday  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun
# 5       Alice      Koala  Female      Normal  Education   19-Aug
# 6        Alli  Alligator  Female      Snooty    Fashion    8-Nov
# 7      Amelia      Eagle  Female      Snooty      Music   19-Nov
# 8    Anabelle   Anteater  Female       Peppy    Fashion   16-Feb
# 9     Anchovy       Bird    Male        Lazy       Play    4-Mar
# 10      Angus       Bull    Male      Cranky    Fitness   30-Apr
# 11   Anicotti      Mouse  Female       Peppy    Fashion   24-Feb
# 12      Ankha        Cat  Female      Snooty     Nature   22-Sep
# ...

# %%
Final_Villagers_ACNH.Personality.unique()
# Out:
# array(['Cranky', 'Peppy', 'Big Sister', 'Lazy', 'Normal', 'Snooty',
#        'Jock', 'Smug'], dtype=object)

# %%
gender_personality = Final_Villagers_ACNH.groupby(['Gender','Personality']).size().reset_index(name = 'count')

# %%
gender_personality
# Out:
#    Gender Personality  count
# 0  Female  Big Sister     24
# 1  Female      Normal     59
# 2  Female       Peppy     49
# 3  Female      Snooty     55
# 4    Male      Cranky     55
# 5    Male        Jock     55
# 6    Male        Lazy     60
# 7    Male        Smug     34

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
#Word Cloud for popular personality traits:
#Gender variable [nominal variable as color of word]
#Personality trait variable [as quantitative sum + size of word]

# %%
text = Final_Villagers_ACNH['Personality'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
text2 = Final_Villagers_ACNH['Catchphrase'].values 

wordcloud = WordCloud().generate(str(text2))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
top15overall=Final_Villagers_ACNH.sort_values(by =['Overall_Popularity'], ascending = False)[0:14]

# %%
top15overall
# Out:
#          Name   Species  Gender Personality      Hobby Birthday Catchphrase  \
# 298   Raymond       Cat    Male        Smug     Nature    1-Oct       crisp
# 87       Clay   Hamster    Male        Lazy     Nature   19-Oct       thump
# 12      Ankha       Cat  Female      Snooty     Nature   22-Sep     me meow
# 59    Bubbles     Hippo  Female       Peppy    Fashion   18-Sep     hipster
# 310       Rod     Mouse    Male        Jock    Fitness   14-Aug         ace
# 232  Merengue     Rhino  Female      Normal     Nature   19-Mar   shortcake
# 3          Al   Gorilla    Male        Lazy    Fitness   18-Oct     ayyyeee
# 186      Judy       Cub  Female      Snooty      Music   10-Mar      myohmy
# 157     Gonzo     Koala    Male      Cranky     Nature   13-Oct        mate
# 228   Marshal  Squirrel    Male        Smug      Music   29-Sep       sulky
# 329     Sherb      Goat    Male        Lazy     Nature   18-Jan      bawwww
# ...

# %%
top15ACPPoll=Final_Villagers_ACNH.sort_values(by =['Poll_Results'], ascending = False)[0:14]

# %%
top15ACPPoll
# Out:
#          Name   Species  Gender Personality    Hobby Birthday Catchphrase  \
# 228   Marshal  Squirrel    Male        Smug    Music   29-Sep       sulky
# 298   Raymond       Cat    Male        Smug   Nature    1-Oct       crisp
# 329     Sherb      Goat    Male        Lazy   Nature   18-Jan      bawwww
# 390    Zucker   Octopus    Male        Lazy   Nature    8-Mar       bloop
# 186      Judy       Cub  Female      Snooty    Music   10-Mar      myohmy
# 227    Marina   Octopus  Female      Normal    Music   26-Jun       blurp
# 345  Stitches       Cub    Male        Lazy     Play   10-Feb    stuffin'
# 12      Ankha       Cat  Female      Snooty   Nature   22-Sep     me meow
# 19      Audie      Wolf  Female       Peppy  Fitness   31-Aug     foxtrot
# 133     Fauna      Deer  Female      Normal   Nature   26-Mar      dearie
# 30       Beau      Deer    Male        Lazy   Nature    5-Apr    saltlick
# 116       Dom     Sheep    Male        Jock     Play   18-Mar  indeedaroo
# ...

# %%
import seaborn as sns

# %%
FinVillagers_ACNH2 = Final_Villagers_ACNH.drop(columns=['Wallpaper', 'Flooring',
                                                        'Furniture List','Filename',
                                                        'Unique Entry ID','Style 2','Color 2'])

# %%
FinVillagers_ACNH2
# Out:
#          Name    Species  Gender Personality      Hobby Birthday  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun
# 5       Alice      Koala  Female      Normal  Education   19-Aug
# 6        Alli  Alligator  Female      Snooty    Fashion    8-Nov
# 7      Amelia      Eagle  Female      Snooty      Music   19-Nov
# 8    Anabelle   Anteater  Female       Peppy    Fashion   16-Feb
# 9     Anchovy       Bird    Male        Lazy       Play    4-Mar
# 10      Angus       Bull    Male      Cranky    Fitness   30-Apr
# 11   Anicotti      Mouse  Female       Peppy    Fashion   24-Feb
# 12      Ankha        Cat  Female      Snooty     Nature   22-Sep
# ...

# %%
#sns.pairplot(FinVillagers_ACNH2)
sns.regplot(y=FinVillagers_ACNH2["Total_Google_Searches"], x=FinVillagers_ACNH2["Poll_Results"],
           color='#c48d3f',fit_reg=False)
#sns.plt.show()
# Out:
# <AxesSubplot:xlabel='Poll_Results', ylabel='Total_Google_Searches'>

# %%
personality_species = Final_Villagers_ACNH.groupby(['Species', 'Personality'])['Overall_Popularity'].sum().unstack().fillna(0)

# %%
personality_species
# Out:
# Personality  Big Sister     Cranky       Jock       Lazy     Normal  \
# Species
# Alligator           0.0   118732.0  1231296.0   594528.0   469964.0
# Anteater            0.0      240.0   561730.0        0.0   500011.0
# Bear           512677.0   426556.0  1253516.0   459957.0   676464.0
# Bird                0.0   202975.0   957328.0  1255470.0   737740.0
# Bull                0.0   706858.0      394.0  1268310.0        0.0
# Cat            551374.0   772129.0   351669.0   786224.0   239531.0
# Chicken        539501.0   417163.0      486.0  1049896.0   587678.0
# Cow                 0.0        0.0        0.0        0.0   523738.0
# Cub            751172.0   622814.0   988624.0  2091325.0  2869752.0
# Deer          1012800.0   818933.0   678263.0  2094844.0   563148.0
# Dog             85095.0   372286.0      801.0  1555704.0   709147.0
# Duck                0.0        0.0   247930.0   887211.0   187705.0
# Eagle               0.0   290153.0   422366.0        0.0   838464.0
# ...

# %%
#personality_overall = Final_Villagers_ACNH.groupby(['Personality'])['Overall_Popularity'].transform('sum').fillna(0)

# %%
Final_Villagers_ACNH['Overall_Popularity'] = Final_Villagers_ACNH[['Overall_Popularity']].astype('int64')

# %%
personality_overall = Final_Villagers_ACNH.groupby(['Personality'])
personality_overall = personality_overall[['Overall_Popularity']].sum().add_prefix('Sum_of_')

# %%
personality_overall
# Out:
#              Sum_of_Overall_Popularity
# Personality
# Big Sister                    11519218
# Cranky                        16029968
# Jock                          17045011
# Lazy                          26341013
# Normal                        25078161
# Peppy                         19729813
# Smug                          18201399
# Snooty                        20743275

# %%
personality_overall.apply(lambda x: x/x.sum()).reset_index()
# Out:
#   Personality  Sum_of_Overall_Popularity
# 0  Big Sister                   0.074467
# 1      Cranky                   0.103628
# 2        Jock                   0.110190
# 3        Lazy                   0.170285
# 4      Normal                   0.162121
# 5       Peppy                   0.127546
# 6        Smug                   0.117665
# 7      Snooty                   0.134098

# %%
from matplotlib import pyplot as plt

# Very simple one-liner using our agg_tips DataFrame.
personality_species.plot(kind='bar', stacked=True,figsize = (16,10),rot = 90,colormap = 'Set2',
                        grid=False,title = 'Popularity by Villager Species and Personality',
                       )

# Just add a title and rotate the x-axis labels to be horizontal.
plt.ylabel('Overall Popularity')
plt.xlabel('Species and Personality')
#plt.xticks(rotation=0, ha='center')
#plt.figure(figsize = (16,20))
# Out:
# Text(0.5, 0, 'Species and Personality')

# %%
#Stacked bar chart:
#Villager species variable [as ordinal rank/order of species x axis & gender bar stack color]
#Total rank by villager species [quantitative variable as sum on y axis]

# %%
#JS Note, they look a bit better unstacked

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=Final_Villagers_ACNH, kind="bar",
    y="Species", x="Overall_Popularity", hue="Gender",
    #order=Final_Villagers_ACNH.sort_values('Species',ascending = False).Overall_Popularity,
    ci =None,palette="Set2", alpha=1, height=16,aspect=14.7/27.27
)
#g.despine(right=True)
#g.title('Overall Popularity from combined Historical Google Searches and ACP Poll Results by Species and Gender')
g.set_axis_labels("Overall Popularity per Million", "Species and Gender")
g.legend.set_title("Gender")
g.set_xticklabels(rotation=45)
#plt.xticks(rotation=45)
#sns.set(rc={'figure.figsize':(40.7,20.27)})

# %%
species_gender = Final_Villagers_ACNH.groupby(['Species','Gender'])['Overall_Popularity'].sum().unstack().fillna(0)

# %%
species_gender
# Out:
# Gender        Female       Male
# Species
# Alligator   470181.0  1944556.0
# Anteater   1064202.0  1376585.0
# Bear       1642313.0  2890562.0
# Bird       1908190.0  3038573.0
# Bull             0.0  1975562.0
# Cat        6028729.0  5833887.0
# Chicken    1127562.0  2068758.0
# Cow        2045991.0        0.0
# Cub        5537765.0  3702763.0
# Deer       2835853.0  5085601.0
# Dog        2881369.0  2668275.0
# Duck       2408038.0  1135551.0
# Eagle      1161850.0   712907.0
# Elephant   1585239.0  1891358.0
# Frog        544367.0  1751382.0
# Goat       1849038.0  2921834.0
# Gorilla     618294.0  2975490.0
# Hamster    1446915.0  5360461.0
# Hippo      3447962.0  1079224.0
# Horse      3375647.0  2435055.0
# Kangaroo   1940149.0   526071.0
# Koala      2470485.0  2619610.0
# Lion             0.0  2315541.0
# Monkey      498468.0  1450325.0
# Mouse      2686364.0  2773992.0
# Octopus    1142223.0  1845501.0
# Ostrich    3213875.0   839441.0
# Penguin    3199850.0  2834281.0
# ...

# %%
# Draw a nested barplot by species and sex
gv2 = species_gender.plot(
    kind="bar",stacked=True,
    alpha=0.8,colormap = 'Set3_r',
    title = 'Overall Popularity by Species and Gender',
    figsize = (18,10), grid = False
)
#g.despine(right=True)
#g.title('Overall Popularity from combined Historical Google Searches and ACP Poll Results by Species and Gender')
#gv2.set_axis_labels("Overall Popularity per Million", "Species and Gender")
#gv2.legend.set_title("Gender")
#gv2.set_xticklabels(rotation=45)
#plt.xticks(rotation=45)
#sns.set(rc={'figure.figsize':(40.7,20.27)})

# %%
personality_gender = Final_Villagers_ACNH.groupby(['Personality','Gender'])['Overall_Popularity'].sum().unstack().fillna(0)

# %%
personality_gender
# Out:
# Gender           Female        Male
# Personality
# Big Sister   11519218.0         0.0
# Cranky              0.0  16029968.0
# Jock                0.0  17045011.0
# Lazy                0.0  26341013.0
# Normal       25078161.0         0.0
# Peppy        19729813.0         0.0
# Smug                0.0  18201399.0
# Snooty       20743275.0         0.0

# %%
# Very simple one-liner using our personality_gender DataFrame.
p = personality_gender.plot(kind='bar', stacked=True,figsize = (15,10),rot = 0,
                           title = 'Popularity by Villager Personality and Gender',
                           grid = False,colormap = 'Set2')

# Just add a title and rotate the x-axis labels to be horizontal.
#plt.xticks(rotation=0, ha='center')
#plt.figure(figsize = (10,15))
#p.sns.set(rc={'figure.figsize':(40.7,20.27)})

# %%
piedata = Final_Villagers_ACNH.groupby(Final_Villagers_ACNH['Gender']).size().reset_index()

# %%
piedata = piedata.rename(columns={0:'Count'})

# %%
piedata.set_index("Gender")
# Out:
#         Count
# Gender
# Female    187
# Male      204

# %%
#Pie chart by villager genders:
#Gender variable [nominal categorical as color & quantitative as count]

piedata1 = piedata['Count'].tolist()
labels = ['Female', 'Male']

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[2:4]

#create pie chart
plt.pie(piedata1, labels = labels,counterclock=False,colors = colors, autopct='%.0f%%',
       startangle = 90)
plt.figure(figsize = (8,10))
plt.show()

# %%
#Bubble chart:
#Species of villagers variable [nominal categorical variable]
#Top ten villager popularity for each gender [color + size]

# %%
top10ACPPoll=Final_Villagers_ACNH.sort_values(by =['Poll_Results'], ascending = False)[0:10]

# %%
top10google=Final_Villagers_ACNH.sort_values(by =['Total_Google_Searches'], ascending = False)[0:10]

# %%
top10acplist= top10ACPPoll['Name'].tolist()
top10googlelist = top10google['Name'].tolist()

# %%
merge10list= top10acplist + top10googlelist
merge10finallist= set(merge10list)
mergelistdf= pd.DataFrame(merge10finallist)

# %%
final_overallpop_df = mergelistdf.merge(Final_Villagers_ACNH,left_on=0,right_on='Name',how='left')

# %%
import plotly.express as px

# %%
fig2 = px.bar(personality_species, color="Personality",title= "Popular Villagers: What Species are they?",
              color_discrete_sequence=px.colors.qualitative.Plotly_r,orientation='h')
fig2.update_traces(textfont_size=18,width=0.85)
fig2.update_layout(font=dict(size=20),title_font_size=24,legend_font_size=19,width=1000,height=600,font_family="Courier",yaxis_title="Villager Species",xaxis_title="Overall Popularity (Google Searches + ACNH Polls)")
fig2.update_layout(height=1000,width=890,autosize=False,font_family="Helvetica",plot_bgcolor='white')
fig2.update_xaxes(showgrid=False,showline=True, tickfont_size=18,ticks='outside',linecolor="black",linewidth=1.5)
fig2.update_yaxes(showgrid=False,showline=True, tickfont_size=18,ticks='outside',linecolor="black",linewidth=1.5)
fig2.update_layout(
    title={
        'text': "Popular Villagers : By Species & Personality",
        'y':0.95,
        'x':0.5})
fig2.update_layout(barmode='stack', yaxis={'categoryorder':'total ascending'})
fig2.show()
# Out:
# <div>                            <div id="7111ad61-9f96-46b4-a3f1-a4ac524d5e34" class="plotly-graph-div" style="height:1000px; width:890px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7111ad61-9f96-46b4-a3f1-a4ac524d5e34")) {                    Plotly.newPlot(                        "7111ad61-9f96-46b4-a3f1-a4ac524d5e34",                        [{"alignmentgroup":"True","hovertemplate":"Personality=Big Sister<br>value=%{x}<br>Species=%{y}<extra></extra>","legendgroup":"Big Sister","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Big Sister","offsetgroup":"Big Sister","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0,0.0,512677.0,0.0,0.0,551374.0,539501.0,0.0,751172.0,1012800.0,85095.0,0.0,0.0,0.0,608.0,566324.0,510261.0,0.0,0.0,1180429.0,586930.0,357344.0,0.0,497227.0,0.0,0.
# ...

# %%
fig3 = px.scatter(final_overallpop_df, x="Poll_Results", y="Total_Google_Searches",size='Poll_Results', color="Personality",hover_name="Name",size_max=60,text='Name',
                  color_discrete_sequence=px.colors.qualitative.Plotly)
fig3.update_traces(textposition='bottom center',textfont_size=19)
fig3.update_layout(font=dict(size=20),height=700,width=980,autosize=False,font_family="Helvetica",plot_bgcolor='white')
fig3.update_xaxes(showgrid=False,showline=True, tickfont_size=18,ticks='outside',linecolor="black",linewidth=1.5)
fig3.update_yaxes(showgrid=False,showline=True, tickfont_size=18,ticks='outside',linecolor="black",linewidth=1.5)
fig3.update_layout(
    title={
        'text': "Top 10 Villagers by Google Searches vs ACNH Polls",
        'y':0.95,
        'x':0.5})
fig3.show()
# Out:
# <div>                            <div id="5d58bfdb-f784-4316-b96d-33b0eaf292e2" class="plotly-graph-div" style="height:700px; width:980px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d58bfdb-f784-4316-b96d-33b0eaf292e2")) {                    Plotly.newPlot(                        "5d58bfdb-f784-4316-b96d-33b0eaf292e2",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Personality=Normal<br>Poll_Results=%{marker.size}<br>Total_Google_Searches=%{y}<br>Name=%{text}<extra></extra>","hovertext":["Fauna","Marina","Merengue"],"legendgroup":"Normal","marker":{"color":"#636EFA","size":[10248.0,11723.0,9646.0],"sizemode":"area","sizeref":7.388888888888889,"symbol":"circle"},"mode":"markers+text","name":"Normal","orientation":"v","showlegend":true,"text":["Fauna","Marina","Merengue"],"x":[102
# ...
